# %%
import csv
import xlrd

workbook = xlrd.open_workbook('C:\Users\talwe\OneDrive\Desktop\Linworth.xlsx')
for sheet in workbook.sheets():
    with open('{}.csv'.format(sheet.name), 'w') as f:
        writer = csv.writer(f)
        writer.writerows(sheet.row_values(row) for row in range(sheet.nrows))

print ("CSV converted")


# need to modify this to ignore 1-9 rows and convert .xlsm to csv from 10th row
# since headers are merged in row 1 and row 2, the csv has two lines which will give wrong starting index name refrence.
# Out:
#   File "<ipython-input-1-99055610985f>", line 4
#     workbook = xlrd.open_workbook('C:\Users\talwe\OneDrive\Desktop\Linworth.xlsx')
#                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

# %%
xl_file = pd.ExcelFile('C:\\Users\\talwe\\OneDrive\\Desktop\\Linworth.xlsx')
dfs = {sheet_name: xl_file.parse(sheet_name) 
          for sheet_name in xl_file.sheet_names}

# %%
dfs['Digital Inputs (VVO)']
# Out:
#                 RTU Point Assignments Sheet  Unnamed: 1  \
# 0                                       NaN         NaN
# 1                        OHLinworthSub_DRTU         NaN
# 2                                       NaN         NaN
# 3    Point Names\nSame Order as DNP 3.0 DPA         NaN
# 4                                       NaN         NaN
# 5                                       NaN         NaN
# 6                                       NaN         NaN
# 7                                       Rev  Adaptivolt
# 8                                       No.     Point #
# 9                                       NaN           0
# 10                                      NaN           1
# 11                                      NaN           2
# 12                                      NaN           3
# 13                                      NaN           4
# 14                                      NaN           5
# 15                                      NaN           6
# 16                                      NaN           7
# 17                                      NaN           8
# 18                                      NaN           9
# 19                                      NaN          10
# 20                                      NaN          11
# 21                                      NaN          12
# 22                                        2          13
# 23                                        2          14
# 24                                        2          15
# 25                                        2          16
# 26                                        2          17
# 27                                        2          18
# 28                                        2          19
# 29                                        2          20
# ..                                      ...         ...
# 419                                     NaN         410
# 420                                     NaN         411
# 421                                     NaN         412
# 422                                     NaN         413
# 423                                     NaN         414
# 424                                     NaN         415
# 425                                     NaN         416
# 426                                     NaN         417
# 427                                     NaN         418
# 428                                     NaN         419
# 429                                     NaN         420
# 430                                     NaN         421
# 431                                     NaN         422
# 432                                     NaN         423
# 433                                     NaN         424
# 434                                     NaN         425
# 435                                     NaN         426
# 436                                     NaN         427
# 437                                     NaN         428
# 438                                     NaN         429
# 439                                     NaN         430
# 440                                     NaN         431
# 441                                     NaN         432
# 442                                     NaN         433
# 443                                     NaN         434
# 444                                     NaN         435
# 445                                     NaN         436
# 446                                     NaN         437
# 447                                     NaN         438
# 448                                     NaN         439
#
#                                 Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0                                      NaN        NaN            NaN
# 1                                      NaN        NaN            NaN
# 2                                      NaN        NaN            NaN
# 3                                      NaN        NaN            NaN
# 4                                      NaN        NaN            NaN
# 5                                      NaN        NaN            NaN
# 6                                      NaN        NaN            NaN
# 7                                      NaN        NaN            RPA
# 8                               Point Name       Code      Device ID
# 9      1012_BI04-13KV CB 7 Circuit Breaker         CB      13KV CB 7
# 10    1012_BI07-13KV CB 13 Circuit Breaker         CB     13KV CB 13
# 11    1012_BI08-13KV CB 14 Circuit Breaker         CB     13KV CB 14
# 12    1012_BI09-13KV CB 12 Circuit Breaker         CB     13KV CB 12
# 13    1012_BI10-13KV CB 15 Circuit Breaker         CB     13KV CB 15
# 14    1012_BI11-13KV CB 16 Circuit Breaker         CB     13KV CB 16
# 15    1012_BI12-13KV CB 11 Circuit Breaker         CB     13KV CB 11
# 16    1012_BI13-13KV CB 10 Circuit Breaker         CB     13KV CB 10
# 17     1012_BI14-13KV CB 9 Circuit Breaker         CB      13KV CB 9
# 18     1012_BI15-13KV CB 8 Circuit Breaker         CB      13KV CB 8
# 19    1013_BI00-13KV CB 17 Circuit Breaker         CB     13KV CB 17
# 20        WDG_00-2_MTWDE1B_XF#2 Relay Comm         RC    MTWDE1B_XF2
# 21        WDG_01-3_MTWDE1B_XF#3 Relay Comm         RC    MTWDE1B_XF3
# 22       WDG_02-8_MTWDE1B_F4808 Relay Comm         RC  MTWDE1B_F4808
# 23       WDG_03-9_MTWDE1B_F4806 Relay Comm         RC  MTWDE1B_F4806
# 24      WDG_04-10_MTWDE1B_F4805 Relay Comm         RC  MTWDE1B_F4805
# 25      WDG_05-11_MTWDE1B_F4807 Relay Comm         RC  MTWDE1B_F4807
# 26      WDG_06-14_MTWDE1B_F4801 Relay Comm         RC  MTWDE1B_F4801
# 27      WDG_07-15_MTWDE1B_F4804 Relay Comm         RC  MTWDE1B_F4804
# 28      WDG_08-16_MTWDE1B_F4803 Relay Comm         RC  MTWDE1B_F4803
# 29      WDG_09-17_MTWDE1B_F4802 Relay Comm         RC  MTWDE1B_F4802
# ..                                     ...        ...            ...
# 419      60243_DI11-CAP-0243 Reclose Block        NaN       CAP-0243
# 420   60243_DI12-CAP-0243 Max Daily Cycles        NaN       CAP-0243
# 421    60243_DI13-CAP-0243 Load Fuse Blown        NaN       CAP-0243
# 422  60243_DI20-CAP-0243 Neutral Sensor LO        NaN       CAP-0243
# 423  60243_DI31-CAP-0243 Operation Inhibit        NaN       CAP-0243
# 424     60244_DI1-CAP-0244 Cap Bank Closed        NaN       CAP-0244
# 425       60244_DI0-CAP-0244 Cap Bank Open        NaN       CAP-0244
# 426         60244_DI2-CAP-0244 Auto Manual        NaN       CAP-0244
# 427        60244_DI3-CAP-0244 Remote Local        NaN       CAP-0244
# 428       60244_DI4-CAP-0244 Alarm Summary        NaN       CAP-0244
# 429     60244_DI7-CAP-0244 SCADA Overriden        NaN       CAP-0244
# 430      60244_DI11-CAP-0244 Reclose Block        NaN       CAP-0244
# 431   60244_DI12-CAP-0244 Max Daily Cycles        NaN       CAP-0244
# 432    60244_DI13-CAP-0244 Load Fuse Blown        NaN       CAP-0244
# 433  60244_DI20-CAP-0244 Neutral Sensor LO        NaN       CAP-0244
# 434  60244_DI31-CAP-0244 Operation Inhibit        NaN       CAP-0244
# 435                      60231____CommFail        NaN       CAP-0231
# 436                      60232____CommFail        NaN       CAP-0232
# 437                      60233____CommFail        NaN       CAP-0233
# 438                      60234____CommFail        NaN       CAP-0234
# 439                      60235____CommFail        NaN       CAP-0235
# 440                      60236____CommFail        NaN       CAP-0236
# 441                      60237____CommFail        NaN       CAP-0237
# 442                      60238____CommFail        NaN       CAP-0238
# 443                      60239____CommFail        NaN       CAP-0239
# 444                      60240____CommFail        NaN       CAP-0240
# 445                      60241____CommFail        NaN       CAP-0241
# 446                      60242____CommFail        NaN       CAP-0242
# 447                      60243____CommFail        NaN       CAP-0243
# 448                      60244____CommFail        NaN       CAP-0244
#
#     Adaptivolt Digital Inputs                 Unnamed: 6  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# 7                         NaN                        NaN
# 8        DAC Point Descriptor        Descriptive Message
# 9             Circuit Breaker     Circuit Breaker Status
# 10            Circuit Breaker     Circuit Breaker Status
# 11            Circuit Breaker     Circuit Breaker Status
# 12            Circuit Breaker     Circuit Breaker Status
# 13            Circuit Breaker     Circuit Breaker Status
# 14            Circuit Breaker     Circuit Breaker Status
# 15            Circuit Breaker     Circuit Breaker Status
# 16            Circuit Breaker     Circuit Breaker Status
# 17            Circuit Breaker     Circuit Breaker Status
# 18            Circuit Breaker     Circuit Breaker Status
# 19            Circuit Breaker     Circuit Breaker Status
# 20           XF2_Comm Failure               Comm Failure
# 21           XF3_Comm Failure               Comm Failure
# 22         F4808_Comm Failure               Comm Failure
# 23         F4806_Comm Failure               Comm Failure
# 24         F4805_Comm Failure               Comm Failure
# 25         F4807_Comm Failure               Comm Failure
# 26         F4801_Comm Failure               Comm Failure
# 27         F4804_Comm Failure               Comm Failure
# 28         F4803_Comm Failure               Comm Failure
# 29         F4802_Comm Failure               Comm Failure
# ..                        ...                        ...
# 419             Reclose Block              Reclose Block
# 420          Max Daily Cycles       Maximum Daily Cycles
# 421           Load Fuse Blown            Load Fuse Blown
# 422         Neutral Sensor LO     Neutral Sensor Lockout
# 423         Operation Inhibit          Operation Inhibit
# 424           Cap Bank Closed      Capacitor Bank Closed
# 425             Cap Bank Open        Capacitor Bank Open
# 426               Auto Manual      Auto/Manual Operation
# 427              Remote Local  Remote/Local Contro lMode
# 428             Alarm Summary              Alarm Summary
# 429           SCADA Overriden     SCADA Override Enabled
# 430             Reclose Block              Reclose Block
# 431          Max Daily Cycles       Maximum Daily Cycles
# 432           Load Fuse Blown            Load Fuse Blown
# 433         Neutral Sensor LO     Neutral Sensor Lockout
# 434         Operation Inhibit          Operation Inhibit
# 435                  CommFail               Comm Failure
# 436                  CommFail               Comm Failure
# 437                  CommFail               Comm Failure
# 438                  CommFail               Comm Failure
# 439                  CommFail               Comm Failure
# 440                  CommFail               Comm Failure
# 441                  CommFail               Comm Failure
# 442                  CommFail               Comm Failure
# 443                  CommFail               Comm Failure
# 444                  CommFail               Comm Failure
# 445                  CommFail               Comm Failure
# 446                  CommFail               Comm Failure
# 447                  CommFail               Comm Failure
# 448                  CommFail               Comm Failure
#
#                        Unnamed: 7 Protocol       Unnamed: 9 Unnamed: 10
# 0                             NaN      NaN              NaN         NaN
# 1                             NaN  DNP 3.0              NaN         NaN
# 2                             NaN      NaN              NaN         NaN
# 3    Data Origination Information      NaN              NaN         NaN
# 4                             NaN      NaN              NaN         NaN
# 5                             NaN      NaN              NaN         NaN
# 6                             NaN      NaN              NaN         NaN
# 7                           State      IED              IED         Pt.
# 8                             1=?  Address             Type       Index
# 9                            Open     1012             2411        BI04
# 10                           Open     1012             2411        BI07
# 11                           Open     1012             2411        BI08
# 12                           Open     1012             2411        BI09
# 13                           Open     1012             2411        BI10
# 14                           Open     1012             2411        BI11
# 15                           Open     1012             2411        BI12
# 16                           Open     1012             2411        BI13
# 17                           Open     1012             2411        BI14
# 18                           Open     1012             2411        BI15
# 19                           Open     1013             2411        BI00
# 20                         Failed    10002             TRTU          00
# 21                         Failed    10002             TRTU          01
# 22                         Failed    10002             TRTU          02
# 23                         Failed    10002             TRTU          03
# 24                         Failed    10002             TRTU          04
# 25                         Failed    10002             TRTU          05
# 26                         Failed    10002             TRTU          06
# 27                         Failed    10002             TRTU          07
# 28                         Failed    10002             TRTU          08
# 29                         Failed    10002             TRTU          09
# ..                            ...      ...              ...         ...
# 419                         Alarm    60243  IntelliCAP 2000          11
# 420                         Alarm    60243  IntelliCAP 2000          12
# 421                         Alarm    60243  IntelliCAP 2000          13
# 422                         Alarm    60243  IntelliCAP 2000          20
# 423                       Inhibit    60243  IntelliCAP 2000          31
# 424                        Closed    60244  IntelliCAP 2000           1
# 425                          Open    60244  IntelliCAP 2000           0
# 426                          Auto    60244  IntelliCAP 2000           2
# 427                        Remote    60244  IntelliCAP 2000           3
# 428                         Alarm    60244  IntelliCAP 2000           4
# 429                       Enabled    60244  IntelliCAP 2000           7
# 430                         Alarm    60244  IntelliCAP 2000          11
# 431                         Alarm    60244  IntelliCAP 2000          12
# 432                         Alarm    60244  IntelliCAP 2000          13
# 433                         Alarm    60244  IntelliCAP 2000          20
# 434                       Inhibit    60244  IntelliCAP 2000          31
# 435                        Failed    60231           Failed     Logical
# 436                        Failed    60232           Failed     Logical
# 437                        Failed    60233           Failed     Logical
# 438                        Failed    60234           Failed     Logical
# 439                        Failed    60235           Failed     Logical
# 440                        Failed    60236           Failed     Logical
# 441                        Failed    60237           Failed     Logical
# 442                        Failed    60238           Failed     Logical
# 443                        Failed    60239           Failed     Logical
# 444                        Failed    60240           Failed     Logical
# 445                        Failed    60241           Failed     Logical
# 446                        Failed    60242           Failed     Logical
# 447                        Failed    60243           Failed     Logical
# 448                        Failed    60244           Failed     Logical
#
# [449 rows x 11 columns]

# %%
dfs.keys()
# Out:
# dict_keys(['Cover Sheet - DSCADA', 'Inside Fence Addressing', 'Outside Fence Addressing', 'Serial Ports DAC', 'Analog Inputs (DSCADA)', 'Digital Inputs (DSCADA)', 'Digital Outputs (DSCADA)', 'Analog Outputs (DSCADA)', 'Binary Counters (DSCADA)', 'WDG - Comm Watchdog', 'Linworth TRTU-DRTU', '5017', '5018', '5019', '5020', '5021', '5022', '5023', '5024', '55100', '55101', '55102', '55103', '55104', '55105', '55106', '55107', '55108', '55109', '55110', '55111', '55112', '55113', '55114', '55115', '55116', '55117', '55118', '55119', '55120', '55121', '55122', '55123', '60231', '60232', '60233', '60234', '60235', '60236', '60237', '60238', '60239', '60240', '60241', '60242', '60243', '60244', 'Cover Sheet - VVO', 'Analog Inputs ', 'Digital Inputs (VVO)', 'Digital Outputs (VVO)', 'Analog Outputs (VVO)', 'Counters (VVO)', 'Adaptivolt Generated Points', 'SMP System Data Points', 'RPA Information Request Form', 'Punch List'])

# %%
dfs['Digital Inputs (VVO)']['Unnamed: 2'][9:]

# %%
feeders = dfs['Inside Fence Addressing']['Unnamed: 4'][4:-5].tolist()
feeders

# %%
f_nums = list(set([entry[-5:-1] for entry in feeders]))
f_nums

# %%
dfs['Analog Inputs ']

# %%
analogs = dfs['Analog Inputs ']['Unnamed: 2'][9:-8]
#analogs = dfs['Analog Inputs ']['Unnamed: 2'][9:-8].tolist()

# %%
#analogs[0]

# %%
analogs.str.split()

# %%
"""
From: 8-09-13.2kV CB8 F-4808 Ph-a MW
To: F4808.MTR.0.P.A
"""

# %%
# Split
# -3: If consists feeder number
# -2: last letter, after ph-
# -1: MW

# %%
mws = [entry for entry in analogs if (entry.endswith("MW") and "F" in entry and "XF" not in entry)]

# %%
mws

# %%
amps = [entry for entry in analogs if (entry.endswith("Amps") and "F" in entry)]
#amps = [entry for entry in analogs if (entry.endswith("Amps") and "F" in entry and "REG" not in entry)]

# %%
amps

# %%
#[words for segments in amps for words in segments.split()]

# %%
my_list =["REG", "CAP", "LVM", "CB", "MLR", "LTC"]
my_list

# %%
# Match names
for element in amps:
     m = re.match("my_list", element)
     if m:
        print(m)

# %%
analogs = dfs['Analog Inputs ']['Unnamed: 2'][54:173]
analogs
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(analogs)
# Out:
# 54          8-01-13.2kV CB8 F-4808 Ph-a Amps
# 55          8-02-13.2kV CB8 F-4808 Ph-b Amps
# 56          8-03-13.2kV CB8 F-4808 Ph-c Amps
# 57       8-19-13.2kV CB8 F-4808 Neutral Amps
# 58                8-04-13.2kV Bus B Ph-an kV
# 59                8-05-13.2kV Bus B Ph-bn kV
# 60                8-06-13.2kV Bus B Ph-cn kV
# 61            8-09-13.2kV CB8 F-4808 Ph-a MW
# 62            8-10-13.2kV CB8 F-4808 Ph-b MW
# 63            8-11-13.2kV CB8 F-4808 Ph-c MW
# 64            8-07-13.2kV CB8 F-4808 3-ph MW
# 65          8-12-13.2kV CB8 F-4808 Ph-a MVar
# 66          8-13-13.2kV CB8 F-4808 Ph-b MVar
# 67          8-14-13.2kV CB8 F-4808 Ph-c MVar
# 68          8-08-13.2kV CB8 F-4808 3-ph MVar
# 69          9-01-13.2kV CB9 F-4806 Ph-a Amps
# 70          9-02-13.2kV CB9 F-4806 Ph-b Amps
# 71          9-03-13.2kV CB9 F-4806 Ph-c Amps
# 72       9-19-13.2kV CB9 F-4806 Neutral Amps
# 73                9-04-13.2kV Bus B Ph-an kV
# 74                9-05-13.2kV Bus B Ph-bn kV
# 75                9-06-13.2kV Bus B Ph-cn kV
# PHASE(CI) dictionary: -a=A, -b=B, -c=C, 3-=3, -an=AN, -bn=BN, -cn=CN, Neutral=N
# UNIT(CI): Amps=I, kV=V, (MW/KW)=P, MVar(CI)=Q
# DEVICETYPE(CI): 
#   CB(DIGITS)=MTR
#   BUS (PHASE=A|B|C)=MTR
# FEEDERID: F-NUMBER|FNUMBER=FNUMBER, unless BUS (raise boolean)

# For MTR: FEEDERID.DEVICETYPE.0.UNIT.PHASE

# %%
#ToDo: Other case variants
phases_ = {'Ph-a':'A', 'Ph-b':'B', 'Ph-c':'C', '3-ph':'3PH', 'Ph-an':'AN', 'Ph-bn':'BN', 'Ph-cn':'CN', 'Neutral':'N'}
units_ = {'Amps':'I', 'kV':'V', 'MW':'P', 'KW':'P', 'MVar':'Q', 'MVAR':'Q'}
devicetype_start_ = {'CB':'MTR'}

# %%
import re

# %%
rtu_meters = []
for name in analogs:
    parts = name.split()
    unit = units_[parts[-1]]
    phase = phases_[parts[-2]]
    if parts[1] == 'Bus':
    
        feeder = rtu_meters[0].split('.')[0]
        devicetype = rtu_meters[0].split('.')[1]
    else:
        devicetype = devicetype_start_[parts[1][:2]]
        feeder = 'FR' + re.findall('\d+', parts[-3])[0]
    rtu_meters.append(feeder + '.' + devicetype + '.' + '0' + '.' + unit + '.'+ phase)

# %%
rtu_meters
# Out:
# ['FR4808.MTR.0.I.A',
#  'FR4808.MTR.0.I.B',
#  'FR4808.MTR.0.I.C',
#  'FR4808.MTR.0.I.N',
#  'FR4808.MTR.0.V.AN',
#  'FR4808.MTR.0.V.BN',
#  'FR4808.MTR.0.V.CN',
#  'FR4808.MTR.0.P.A',
#  'FR4808.MTR.0.P.B',
#  'FR4808.MTR.0.P.C',
#  'FR4808.MTR.0.P.3PH',
#  'FR4808.MTR.0.Q.A',
#  'FR4808.MTR.0.Q.B',
#  'FR4808.MTR.0.Q.C',
#  'FR4808.MTR.0.Q.3PH',
#  'FR4806.MTR.0.I.A',
#  'FR4806.MTR.0.I.B',
#  'FR4806.MTR.0.I.C',
#  'FR4806.MTR.0.I.N',
#  'FR4808.MTR.0.V.AN',
#  'FR4808.MTR.0.V.BN',
#  'FR4808.MTR.0.V.CN',
#  'FR4806.MTR.0.P.A',
#  'FR4806.MTR.0.P.B',
#  'FR4806.MTR.0.P.C',
#  'FR4806.MTR.0.P.3PH',
#  'FR4806.MTR.0.Q.A',
#  'FR4806.MTR.0.Q.B',
#  'FR4806.MTR.0.Q.C',
#  'FR4806.MTR.0.Q.3PH',
#  'FR4805.MTR.0.I.A',
#  'FR4805.MTR.0.I.B',
#  'FR4805.MTR.0.I.C',
#  'FR4805.MTR.0.I.N',
#  'FR4808.MTR.0.V.AN',
#  'FR4808.MTR.0.V.BN',
#  'FR4808.MTR.0.V.CN',
#  'FR4805.MTR.0.P.A',
#  'FR4805.MTR.0.P.B',
#  'FR4805.MTR.0.P.C',
#  'FR4805.MTR.0.P.3PH',
#  'FR4805.MTR.0.Q.A',
#  'FR4805.MTR.0.Q.B',
#  'FR4805.MTR.0.Q.C',
#  'FR4805.MTR.0.Q.3PH',
#  'FR4807.MTR.0.I.A',
#  'FR4807.MTR.0.I.B',
#  'FR4807.MTR.0.I.C',
#  'FR4807.MTR.0.I.N',
#  'FR4808.MTR.0.V.AN',
#  'FR4808.MTR.0.V.BN',
#  'FR4808.MTR.0.V.CN',
#  'FR4807.MTR.0.P.A',
#  'FR4807.MTR.0.P.B',
#  'FR4807.MTR.0.P.C',
#  'FR4807.MTR.0.P.3PH',
#  'FR4807.MTR.0.Q.A',
#  'FR4807.MTR.0.Q.B',
#  'FR4807.MTR.0.Q.C',
#  'FR4807.MTR.0.Q.3PH',
#  'FR4801.MTR.0.I.A',
#  'FR4801.MTR.0.I.B',
#  'FR4801.MTR.0.I.C',
#  'FR4801.MTR.0.I.N',
#  'FR4808.MTR.0.V.AN',
#  'FR4808.MTR.0.V.BN',
#  'FR4808.MTR.0.V.CN',
#  'FR4801.MTR.0.P.A',
#  'FR4801.MTR.0.P.B',
#  'FR4801.MTR.0.P.C',
#  'FR4801.MTR.0.P.3PH',
#  'FR4801.MTR.0.Q.A',
#  'FR4801.MTR.0.Q.B',
#  'FR4801.MTR.0.Q.C',
#  'FR4801.MTR.0.Q.3PH',
#  'FR4804.MTR.0.I.A',
#  'FR4804.MTR.0.I.B',
#  'FR4804.MTR.0.I.C',
#  'FR4804.MTR.0.I.N',
#  'FR4808.MTR.0.V.AN',
#  'FR4808.MTR.0.V.BN',
#  'FR4808.MTR.0.V.CN',
#  'FR4804.MTR.0.P.A',
#  'FR4804.MTR.0.P.B',
#  'FR4804.MTR.0.P.C',
#  'FR4804.MTR.0.P.3PH',
#  'FR4804.MTR.0.Q.A',
#  'FR4804.MTR.0.Q.B',
#  'FR4804.MTR.0.Q.C',
#  'FR4804.MTR.0.Q.3PH',
#  'FR4803.MTR.0.I.A',
#  'FR4803.MTR.0.I.B',
#  'FR4803.MTR.0.I.C',
#  'FR4803.MTR.0.I.N',
#  'FR4808.MTR.0.V.AN',
#  'FR4808.MTR.0.V.BN',
#  'FR4808.MTR.0.V.CN',
#  'FR4803.MTR.0.P.A',
#  'FR4803.MTR.0.P.B',
#  'FR4803.MTR.0.P.C',
#  'FR4803.MTR.0.P.3PH',
#  'FR4803.MTR.0.Q.A',
#  'FR4803.MTR.0.Q.B',
#  'FR4803.MTR.0.Q.C',
#  'FR4803.MTR.0.Q.3PH',
#  'FR4802.MTR.0.I.A',
#  'FR4802.MTR.0.I.B',
#  'FR4802.MTR.0.I.C',
#  'FR4802.MTR.0.I.N',
#  'FR4808.MTR.0.V.AN',
#  'FR4808.MTR.0.V.BN',
#  'FR4808.MTR.0.V.CN',
#  'FR4802.MTR.0.P.A',
#  'FR4802.MTR.0.P.B',
#  'FR4802.MTR.0.P.C',
#  'FR4802.MTR.0.P.3PH',
#  'FR4802.MTR.0.Q.A',
#  'FR4802.MTR.0.Q.B',
#  'FR4802.MTR.0.Q.C']
